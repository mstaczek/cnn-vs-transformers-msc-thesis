# %%
# read 4 png files
gradcam_cosine = '../20240414-2-gradcam-1024-fixed-efficientnet-b4/pca_cosine.png'
gradcam_rbf = '../20240414-2-gradcam-1024-fixed-efficientnet-b4/pca_rbf.png'
kernelshap_cosine = '../20240410-kernelshap-64/pca_cosine.png'
kernelshap_rbf = '../20240410-kernelshap-64/pca_rbf.png'

import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].imshow(plt.imread(gradcam_cosine))
axs[0, 0].set_title('GradCAM cosine')
axs[0, 0].axis('off')
axs[0, 1].imshow(plt.imread(gradcam_rbf))
axs[0, 1].set_title('GradCAM rbf')
axs[0, 1].axis('off')
axs[1, 0].imshow(plt.imread(kernelshap_cosine))
axs[1, 0].set_title('KernelSHAP cosine')
axs[1, 0].axis('off')
axs[1, 1].imshow(plt.imread(kernelshap_rbf))
axs[1, 1].set_title('KernelSHAP rbf')
axs[1, 1].axis('off')
plt.tight_layout()
plt.savefig('pca_gradcam_kernelshap_comparison.png')
plt.show()
